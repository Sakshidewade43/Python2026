# %% [markdown]
# ### 1. Write a program to add two lists index-wise. Create a new list that contains the 0th index item from both the list, then the 1st index item, and so on till the last element. any leftover items will get added at the end of the new list.

# %%
lst1 = ["M", "na", "i", "Ra"]
lst2 = ["y", "me", "s", "hul"]
# Out:
# [['M', 'na', 'i', 'Ra', 'y', 'me', 's', 'hul']]

# %% [markdown]
# ### 2)Write a program to add item 7000 after 6000 in the following Python List

# %%
lst1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]
lst1[2][2].append(7000)
lst1
# Out:
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

# %% [markdown]
# ### 3)Suppose you are given a list of candy and another list of same size representing no of items of respective candy.

# %%
candy_lst = ['Jelly Belly','Kit Kat','Double Bubble','Milky Way','Three Musketeers']
no_of_items = [10,20,34,74,32]
list(zip(candy_lst,no_of_items))
# Out:
# [('Jelly Belly', 10),
#  ('Kit Kat', 20),
#  ('Double Bubble', 34),
#  ('Milky Way', 74),
#  ('Three Musketeers', 32)]

# %% [markdown]
# ### 4. Running Sum on list Write a program to print a list after performing running sum on it.

# %%
lst1 = [1,2,3,4,5,6]
count=0
l=[]
for i in lst1:
    count+=i
    l.append(count)
print(l)
# Out:
# [1, 3, 6, 10, 15, 21]

# %% [markdown]
# ### 5. You are given a list of integers. You are asked to make a list by running through elements of the list by adding all elements greater and itself.

# %%
lst=[2,4,6,10,1]
l=[]
for i in lst:
    x=0
    for j in (lst):
        if j>=i:
            x+=j
    l.append(x)
            
print(l)

# %% [markdown]
# ### 6. Find list of common unique items from two list. and show in increasing order

# %%
num1 = [23,45,67,78,89,34]
num2 = [34,89,55,56,39,67]
num3=set(num1)
x=num3.intersection(num2)
num4=list(x)
print(num4)
# Out:
# [89, 34, 67]

# %% [markdown]
# ### 7. Sort a list of alphanumeric strings based on product value of numeric character in it. If in any string there is no numeric character take it's product value as 1.

# %%
l = ['1ac21', '23fg', '456', '098d','1','kls']

l1=[]
l2=[]

for i in l:
    if i.isalnum():
        l1.append(i)
        for j in i:
            if j.isdigit():
                l2.append(j)
                # print(j)


l1
l2
# Out:
# ['1', '2', '1', '2', '3', '4', '5', '6', '0', '9', '8', '1']

# %%
# prod = 1
# l1=[]
# for i in l:
#   l2=[]
#   if i.isalnum()==True:
#     for j in i:
#       if j.isdigit() == True:
#         l2.append(int(j))
#   else:
#     l2.append(1)
#   l1.append(math.prod(l2))

# # l = ['1ac21', '23fg', '456', '098d','1','kls']
# # l1 = [2, 6, 120, 0, 1, 1]

# a = zip(l1,l)
# # print(list(a))
# b= sorted(a,reverse=True)
# b
# [j for i,j in b]

# %% [markdown]
# ### 8. Write a program that can find the max number of each row of a matrix
# 	Example:

# %%
lst=[[1,2,3],[4,5,6],[7,8,9]]
l=[]
for i in lst:
    # print(max(i))
    l.append(max(i))
print(l)
# Out:
# [3, 6, 9]

# %% [markdown]
# ### 9.Shortlist Students for a Job role Ask user to input students record and store in tuples for each record. Then Ask user to input three things he wants in the candidate- Primary Skill, Higher Education, Year of Graduation.
#
# 	Show every students record in form of tuples if matches all required criteria.
#
# 	It is assumed that there will be only one primry skill.
#
# 	If no such candidate found, print No such candidate
#
# 	Input:
#
# 	Enter No of records- 2
# 	Enter Details of student-1
# 	Enter Student name- Manohar
# 	Enter Higher Education- B.Tech
# 	Enter Primary Skill- Python
# 	Enter Year of Graduation- 2022
# 	Enter Details of student-2
# 	Enter Student name- Ponian
# 	Enter Higher Education- B.Sc.
# 	Enter Primary Skill- C++
# 	Enter Year of Graduation- 2020
#
# 	Enter Job Role Requirement
# 	Enter Skill- Python
# 	Enter Higher Education- B.Tech
# 	Enter Year of Graduation- 2022
# 	Output
#
# 	('Manohar', 'B.tech', 'Python', '2022')

# %%
l1=[]

Enter_Higher_Education= "B.Tech"
l1.append(Enter_Higher_Education)
Enter_Primary_Skill= "Python"
l1.append(Enter_Primary_Skill)
Enter_Year_of_Graduation= 2022
l1.append(Enter_Year_of_Graduation)
# print(l1)

l2=[]
Enter_Higher_Education="B.Sc"
l2.append(Enter_Higher_Education)
Enter_Primary_Skill= "C++"
l2.append(Enter_Primary_Skill)
Enter_Year_of_Graduation= 2020
l2.append(Enter_Year_of_Graduation)
# print(l2)

R=[]
Enter_Skill= "Python"
R.append(Enter_Skill)
Enter_Higher_Education= "B.Tech"
R.append(Enter_Higher_Education)
Enter_Year_of_Graduation= 2022
R.append(Enter_Year_of_Graduation)
# print(R)


if l1==R:
    print("yes l1 is matche")
elif l2==R:
    print("yes l2 is matche")
else:
    print("No such candidate")
# Out:
# No such candidate

# %%
n="Enter No of records- 2"


a=input("Enter Details of student")
# b=input("Enter Student1 name")
# c=input("Enter Higher Education")
# d=input("Enter Primary Skill")
e=int(input("Enter Year of Graduation"))

# student2=Enter Details of student-2
# Enter Student name- Ponian
# Enter Higher Education- B.Sc.
# Enter Primary Skill- C++
# Enter Year of Graduation- 2020

# Requirement="""
# # Enter Skill- Python
# # 	Enter Higher Education- B.Tech
# # 	Enter Year of Graduation- 2022"""

if skill=="python" and education=="B.Tect" and graduation==2022:
    print(" matches all required criteria")
else:
    print("no such candidate found")
# Out:
# Enter Details of student sakshi
# Enter Higher Education B.Tect
# Enter Year of Graduation 2022
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[146], line 21
#       8 e=int(input("Enter Year of Graduation"))
#      10 # student2=Enter Details of student-2
#      11 # Enter Student name- Ponian
#      12 # Enter Higher Education- B.Sc.
#    (...)
#      18 # # 	Enter Higher Education- B.Tech
#      19 # # 	Enter Year of Graduation- 2022"""
# ---> 21 if skill=="python" and education=="B.Tect" and graduation==2022:
#      22     print(" matches all required criteria")
#      23 else:
#
# NameError: name 'skill' is not defined

# %% [markdown]
# ### 10. Write a program to find set of common elements in three lists using sets.

# %%
ar1 = [1, 5, 10, 20, 40, 80]
ar2 = [6, 7, 20, 80, 100]
ar3 = [3, 4, 15, 20, 30, 70, 80, 120]
s1=set(ar1)
s2=s1.intersection(ar2,ar3)
s2=list(s2)
print(s2)
# Out:
# [80, 20]

# %% [markdown]
# ### 11. Write a program to count unique number of vowels using sets in a given string. Lowercase and upercase vowels will be taken as different.

# %%
str1 = "hands-on data science mentorship progrAm with live classes at affordable fee only on CampusX"
s=set(str1)
vowel="aeiou,AEIOU"
l1=set()
for i in s:
    if i in vowel:
        l1.add(i)
print(l1)  
print("No of unique vowels:",len(l1))
# Out:
# {'a', 'e', 'u', 'i', 'A', 'o'}
# No of unique vowels: 6

# %% [markdown]
# ### 12. Intersection of two lists. Intersection of two list means we need to take all those elements which are common to both of the initial lists and store them into another list. Only use using list-comprehension.
#
# lst1 = {15, 9, 10, 56, 23, 78, 5, 4, 9}
# 	lst2 = {9, 4, 5, 36, 47, 26, 10, 45, 87}
# 	Output:
#
# 	[9, 10, 4, 5]
# 	Example 2:
#
# 	Input:
#
# 	lst1 = {4, 9, 1, 17, 11, 26, 28, 54, 69}
# 	lst2 = {9, 9, 74, 21, 45, 11, 63, 28, 26}
# 	Output:
#
# 	[9, 11, 26, 28]

# %%
# 1NHYB V
lst1 = {15, 9, 10, 56, 23, 78, 5, 4, 9} 
lst2 = {9, 4, 5, 36, 47, 26, 10, 45, 87}

new_list=[i for i in lst1 if i in lst2]
new_list
# Out:
# [4, 5, 9, 10]

# %%
# 2
lst1 = {4, 9, 1, 17, 11, 26, 28, 54, 69}
lst2 = {9, 9, 74, 21, 45, 11, 63, 28, 26}

new_list=[ i for i in lst1 if i in lst2]
new_list
# Out:
# [9, 11, 26, 28]

# %% [markdown]
# ### 13. Convert a list of Tuples into Dictionary.
# 	Example 1:

# %%
# 1)
lst=[("akash", 10), ("gaurav", 12), ("anand", 14), ("suraj", 20), ("akhil", 25), ("ashish", 30)]
d={}
for i,j in lst:
    d[i]=[j]
print(d)
# Out:
# {'akash': [10], 'gaurav': [12], 'anand': [14], 'suraj': [20], 'akhil': [25], 'ashish': [30]}

# %%
# 2)
lst=[('A', 1), ('B', 2), ('C', 3)]
d={}
for i,j in lst:
    d[i]=[j]
print(d)
# Out:
# {'A': [1], 'B': [2], 'C': [3]}

# %% [markdown]
# ### 14. Write a Python function that takes a list and returns a new list with unique elements of the first list.
# 	Exercise 1:

# %%
l=[1,2,3,3,3,3,4,5]
s1=set(l)

s2=list(s1)
s2
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### 15.  Write a Python program to print the even numbers from a given list.
# 		Sample List : [1, 2, 3, 4, 5, 6, 7, 8, 9]
# 		Expected Result : [2, 4, 6, 8]

# %%
l= [1, 2, 3, 4, 5, 6, 7, 8, 9]
l1=[]
for i in l:
    if i%2==0:
        print(i)
        l1.append(i)
print(l1)
# Out:
# 2
# 4
# 6
# 8
# [2, 4, 6, 8]

# %% [markdown]
# ### 16. Write a Python function to check whether a number is perfect or not.¶
# 	A Perfect number is a number that is half the sum of all of its positive divisors (including itself).
#
# 	Example :
#
# 	The first perfect number is 6, because 1, 2, and 3 are its proper positive divisors, and 1 + 2 + 3 = 6.
# 	Equivalently, the number 6 is equal to half the sum of all its positive divisors: ( 1 + 2 + 3 + 6 ) / 2 = 6.
#
# 	The next perfect number is 28 = 1 + 2 + 4 + 7 + 14. This is followed by the perfect numbers 496 and 8128.

# %%
n=int(input("enter the number"))
count=0
for i in range(1,n):
    if n%2==0:
        count+=i
if count==n:
    print("perfact number")
else:
    print("not a perfact number")
# Out:
# enter the number 6
# not a perfact number

# %% [markdown]
# ### 17. Write a Python function to concatenate any no of dictionaries to create a new one.
# 	Sample Dictionary :
# 	dic1={1:10, 2:20}
# 	dic2={3:30, 4:40}
# 	dic3={5:50,6:60}

# %%
dic1 = {1:10, 2:20}
dic2 = {3:30, 4:40}
dic3 = {5:50, 6:60}

# concatenate(dic1, dic2, dic3)
def concatenate_dict(a,b,c):
    addition=dic1|dic2|dic3
    return addition
concatenate_dict(dic1,dic2,dic3)
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %% [markdown]
# ### 18. Write a python function that receives a list of integers and prints out a histogram of bin size 10
#
# 	Input:
# 	[13,42,15,37,22,39,41,50]

# %%
x=[13,42,15,37,22,39,41,50]

def histogram(x):
    for i in x:
        if 11 <= i <= 20:
            pass
        elif 21 <= i <= 30:
            pass
        elif 31 <= i <= 40:
            pass
        elif 41 <= i <= 50:
            return i
histogram(x)
# Out:
# 42
